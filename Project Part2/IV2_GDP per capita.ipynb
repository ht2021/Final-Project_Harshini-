# %%
## Importing required packages
import pandas as pd 
import numpy as np

# %%
##Loading Greenhouse gas emissions latest available data 2017
raw_data_iv2 = pd.read_csv("C:/Users/VIOLIN/Desktop/Final-Project_Harshini-/Project Part -2/Data part2/IV2_GDP data.csv")
##Printing data
raw_data_iv2.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  ...  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 1  59.773194  59.860874  58.458015  78.706388  82.095231  101.108305  ...
# 2        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN         NaN  ...
#
#            2011          2012          2013          2014          2015  \
# ...

# %%
## Let us filter the required columns 

IV2 =raw_data_iv2[["Country Name","2019"]] 

IV2.columns = ['country','2019 GDP per capita']

IV2.head()
# Out:
#        country  2019 GDP per capita
# 0        Aruba                  NaN
# 1  Afghanistan           502.115487
# 2       Angola          2973.591160
# 3      Albania          5352.857411
# 4      Andorra         40886.391160

# %%
 #checking how much invalid data exists
    # to determine if data is valid
IV2.isnull().sum()
# Out:
# country                 0
# 2019 GDP per capita    41
# dtype: int64

# %%
## Let us fill the missing values with -999

IV2.replace(to_replace = np.nan, value = -999)
# Out:
#           country  2019 GDP per capita
# 0           Aruba          -999.000000
# 1     Afghanistan           502.115487
# 2          Angola          2973.591160
# 3         Albania          5352.857411
# 4         Andorra         40886.391160
# ..            ...                  ...
# 259        Kosovo          4417.509940
# 260   Yemen, Rep.          -999.000000
# 261  South Africa          6001.400814
# 262        Zambia          1291.343357
# 263      Zimbabwe          1463.985910
#
# [264 rows x 2 columns]

# %%
##creating a output csv file
IV2.to_csv("C:/Users/VIOLIN/Desktop/Final-Project_Harshini-/Project Part -2/Processed data part2/IV2_output.csv", sep=',',index=False)
