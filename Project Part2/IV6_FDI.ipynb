# %%
## Importing required packages
import pandas as pd 
import numpy as np

# %%
raw_data_IV6 = pd.read_csv("C:/Users/VIOLIN/Desktop/Final-Project_Harshini-/Project Part -2/Data part2/FDI Data.csv")
##Printing data
raw_data_IV6.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 1  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 2  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 3  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 4  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
#
#    1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  4.881564e+08 -3.146927e+08
# 1   NaN   NaN   NaN   NaN   NaN  ...  5.217342e+07  5.682366e+07
# 2   NaN   NaN   NaN   NaN   NaN  ... -3.023771e+09 -1.464628e+09
# ...

# %%
IV6 = raw_data_IV6[['Country Name','2019']]
IV6.columns = ['country','2019 FDI data']

IV6.head()
# Out:
#        country  2019 FDI data
# 0        Aruba  -7.604174e+07
# 1  Afghanistan   2.340455e+07
# 2       Angola  -4.098479e+09
# 3      Albania   1.201022e+09
# 4      Andorra            NaN

# %%
 #checking how much invalid data exists
    # to determine if data is valid
IV6.isnull().sum()
# Out:
# country           0
# 2019 FDI data    22
# dtype: int64

# %%
## Let us fill the missing values with -999

IV6.replace(to_replace = np.nan, value = -999)
# Out:
#           country  2019 FDI data
# 0           Aruba  -7.604174e+07
# 1     Afghanistan   2.340455e+07
# 2          Angola  -4.098479e+09
# 3         Albania   1.201022e+09
# 4         Andorra  -9.990000e+02
# ..            ...            ...
# 259        Kosovo   3.040855e+08
# 260   Yemen, Rep.  -3.709828e+08
# 261  South Africa   4.624503e+09
# 262        Zambia   5.479679e+08
# 263      Zimbabwe   2.800000e+08
#
# [264 rows x 2 columns]

# %%
##creating a output csv file
IV6.to_csv("C:/Users/VIOLIN/Desktop/Final-Project_Harshini-/Project Part -2/Processed data part2/IV6_output.csv", sep=',',index=False)
